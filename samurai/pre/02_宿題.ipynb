# %% [markdown]
# ### list, numpy, dataframe(series)をそれぞれ相互に変換する方法を調べて実装してください.

# %%
# list -> numpy

# %%
# numpy -> list

# %%
# numpy -> dataframe

# %%
# dataframe -> numpy

# %%
# list -> dataframe

# %%
# series -> list
