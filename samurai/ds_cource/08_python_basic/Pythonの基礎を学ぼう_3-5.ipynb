# %% [markdown]
# # ３章: Pythonの基本的な書き方を理解しよう

# %%
age = 18 # 年齢

if age < 20:
    # 未成年の場合
    print("ジュースで乾杯！")
else:
    # 成年の場合
    print("お酒で乾杯！")

# %% [markdown]
# *  文の最後にセミコロン（；）は不要
# * 中かっこ｛｝で囲わず、インデントする(Tabボタン押下で自動スペース)
#     * 右上歯車 > エディタ > インデントの箇所で2から4へ変更する
# * コメントにはシャープ（\#）、複数行コメントはクォーテーション（'''）を使う

# %% [markdown]
# ### **実践: クォーテーションを用いて3行コメントしてみましょう**

# %%
age = 18 # 年齢
age_threshold = 20
if age < age_threshold:
    # 未成年の場合
    print("ジュースで乾杯！")
else:
    """
    コメントします
    複数行コメントできます
    便利です
    """
    print("お酒で乾杯！")

# %% [markdown]
# # ４章: データの扱い方を理解しよう

# %%
# シングルクォーテーション
print('こんにちは')

# ダブルクォーテーション
print("今日はいい天気ですね")

# %%
print(100)

# %%
print(１００)

# %%
print("１００")

# %% [markdown]
# ### **実践: 実際に何かしらの数値と文字を含めてprintしてみましょう**

# %%
print(100-99.9)
# Out:
# 0.09999999999999432

# %%
print(type(100))
# Out:
# <class 'int'>

# %%
print(True)

judge = True
print(type(judge))

judge = 100
print(type(judge))

judge = False
print(type(judge))
# Out:
# True
# <class 'bool'>
# <class 'int'>
# <class 'bool'>

# %%
print(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d6f700e50a15> in <cell line: 1>()
# ----> 1 print(true)
#
# NameError: name 'true' is not defined

# %%
print(45 + 18)
print(30 - 12)
print(15 * 6)
print(30 / 3)
print(45 % 8)

# %%
print(type(30/3))

# %%
print(45 + 1.8)
print(3 - 1.2)
print(15 * 0.6)
print(3 / 0.3)
print(45 % 0.8)

# %%
print((10+50)*2)

# %%
# 推奨
print("今日の天気は" + "晴れ")

# 非推奨
print("今日の天気は" "曇り")

# %%
print("降水確率" + 50 + "%")

# %%
print("降水確率" + str(50) + "%")

# %%
rain_percent = 50
print(f"降水確率{rain_percent}%")

# %%
print("晴れ" * 5)
print("晴れ" + "晴れ" + "晴れ" + "晴れ" + "晴れ")

# %% [markdown]
# ### **実践: 以下の文章を出力してください。その際、数値は+とstrを用いて文字列へ変換してください**
# 10から1を引くと9になります。

# %% [markdown]
# # 5章: 変数を理解しよう

# %%
user_name = "侍太郎"

# 発展(実務寄り)
user_name2: str = "侍太郎2"

print(user_name)
print(user_name2)

# %%
# 5.4 変数の中身を入れ替えてみよう
user_name: str = "侍太郎"
print(user_name)
user_name: str = "侍花子"
print(user_name)

# %%
#5.5 変数を使って数値の計算や文字列の連結をしてみよう
number1 = 5
number2 = 2.5
print(number1 + number2)

# 文字列型と文字列型の連結
last_name  = "侍"
first_name = "太郎"
print(last_name + first_name)

# %%
#補足：文字列の中で変数の中身を表示する方法
last_name   = "侍"
first_name  = "太郎"
sister_name = "花子"

# 3つの変数を文字列内に埋め込んで表示
print(f"私の名前は{last_name}{first_name}です。妹の名前は{sister_name}です。")

# 以前の記載
print("私の名前は{}{}です.".format(last_name, first_name))

# %%
# 5.6 変数名のつけ方ルール（命名規則）
# create_number
# add_value
# contains_value
# exists_person
# age, tel_number, person_age, family_number

# %% [markdown]
# ### **実践: 以下の100と30を変数に格納し、以下の結果を出力してください。その際、fを用いてください。**
# 100から30を引くと70になる。

# %% [markdown]
# ### **実践: 以下をスネークケースで変数名定義してください**
# * 家族の人数
# * 算数の点数
# * 子供の名前

# %% [markdown]
# # 課題: 変数を使って四則演算しよう
# * リポジトリ名「python-basic-kadai」

# %% [markdown]
# # 課題後の実践1:
# 1. 以下の処理をgithubにアップロードする(python-basic-kadaiリポジトリ内にpractice_05_01フォルダを作成しそこに格納する)
#     1. 3つの変数を用いて文字列と数値２つを代入する
#     1. f-stringを用いてすべてをアンダーバーで結合した結果を出力する

# %%
# 1. 3つの変数を定義
var1 = "Python"
var2 = 42
var3 = 3.14

# 2. f-stringを用いてすべてをアンダーバーで結合した結果を出力
result = f"{var1}_{var2}_{var3}"
print(result)

# %% [markdown]
# # 課題後の実践2:
# 1. 以下の処理をgithubにアップロードする(python-basic-kadaiリポジトリ内にpractice_05_02フォルダを作成しそこに格納する)
#     1. 変数に四則演算の結果を格納する(varA1～VarA5とする, ただし適切な名前に変更すること)
#     1. 変数に四則演算の何を実施するか文字列で格納する(varBとする, ただし適切な名前に変更すること)
#     1. fを用いて"加算の結果は40です"のように出力する。加算や結果の数値は変数で出力すること

# %%
# 1. 変数に四則演算の結果を格納する
addition_result = 20 + 20
subtraction_result = 50 - 10
multiplication_result = 5 * 4
division_result = 100 / 5
modulus_result = 17 % 4

# 2. 変数に四則演算の何を実施するか文字列で格納する
operation_name = "加算"

# 3. fを用いて"加算の結果は40です"のように出力する
print(f"{operation_name}の結果は{addition_result}です")
