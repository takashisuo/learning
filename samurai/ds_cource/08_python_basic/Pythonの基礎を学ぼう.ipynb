# %% [markdown]
# # ３章: Pythonの基本的な書き方を理解しよう

# %%
age = 18 # 年齢

if age < 20:
    # 未成年の場合
    print("ジュースで乾杯！")
else:
    # 成年の場合
    print("お酒で乾杯！")
# Out:
# ジュースで乾杯！

# %% [markdown]
# *  文の最後にセミコロン（；）は不要
# * 中かっこ｛｝で囲わず、インデントする(Tabボタン押下で自動スペース)
#     * 右上歯車 > エディタ > インデントの箇所で2から4へ変更する
# * コメントにはシャープ（\#）、複数行コメントはクォーテーション（'''）を使う

# %% [markdown]
# ### **実践: クォーテーションを用いて3行コメントしてみましょう**

# %% [markdown]
# # ４章: データの扱い方を理解しよう

# %%
# シングルクォーテーション
print('こんにちは')

# ダブルクォーテーション
print("今日はいい天気ですね")
# Out:
# こんにちは
# 今日はいい天気ですね

# %%
print(100)
# Out:
# 100

# %%
print(１００)
# Out:
#   File "<ipython-input-7-deb3f2c376e5>", line 1
#     print(１００)
#           ^
# SyntaxError: invalid character '１' (U+FF11)

# %%
print("１００")
# Out:
# １００

# %% [markdown]
# ### **実践: 実際に何かしらの数値と文字を含めてprintしてみましょう**

# %%
print(100-99.9)
# Out:
# 0.09999999999999432

# %%
print(True)
# Out:
# True

# %%
print(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d6f700e50a15> in <cell line: 1>()
# ----> 1 print(true)
#
# NameError: name 'true' is not defined

# %%
print(45 + 18)
print(30 - 12)
print(15 * 6)
print(30 / 3)
print(45 % 8)
# Out:
# 63
# 18
# 90
# 10.0
# 5

# %%
print(type(30/3))
# Out:
# <class 'float'>

# %%
print(45 + 1.8)
print(3 - 1.2)
print(15 * 0.6)
print(3 / 0.3)
print(45 % 0.8)
# Out:
# 46.8
# 1.8
# 9.0
# 10.0
# 0.1999999999999975

# %%
print((10+50)*2)
# Out:
# 120

# %%
# 推奨
print("今日の天気は" + "晴れ")

# 非推奨
print("今日の天気は" "曇り")
# Out:
# 今日の天気は晴れ
# 今日の天気は曇り

# %%
print("降水確率" + 50 + "%")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e8f92d234b59> in <cell line: 1>()
# ----> 1 print("降水確率" + 50 + "%")
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("降水確率" + str(50) + "%")
# Out:
# 降水確率50%

# %%
print(f"降水確率{50+10}%")
# Out:
# 降水確率60%

# %%
print("晴れ" * 5)
print("晴れ" + "晴れ" + "晴れ" + "晴れ" + "晴れ")
# Out:
# 晴れ晴れ晴れ晴れ晴れ
# 晴れ晴れ晴れ晴れ晴れ

# %% [markdown]
# ### **実践: 以下の文章を出力してください。その際、数値は+とstrを用いて文字列へ変換してください**
# 10から1を引くと9になります。

# %% [markdown]
# # 5章: 変数を理解しよう

# %%
user_name = "侍太郎"

# 発展(実務寄り)
user_name2: str = "侍太郎2"

print(user_name)
print(user_name2)
# Out:
# 侍太郎
# 侍太郎2

# %%
# 5.4 変数の中身を入れ替えてみよう
user_name: str = "侍太郎"
print(user_name)
user_name: str = "侍花子"
print(user_name)
# Out:
# 侍太郎
# 侍花子

# %%
#5.5 変数を使って数値の計算や文字列の連結をしてみよう
number1 = 5
number2 = 2.5
print(number1 + number2)

# 文字列型と文字列型の連結
last_name  = "侍"
first_name = "太郎"
print(last_name + first_name)
# Out:
# 7.5
# 侍太郎

# %%
#補足：文字列の中で変数の中身を表示する方法
last_name   = "侍"
first_name  = "太郎"
sister_name = "花子"

# 3つの変数を文字列内に埋め込んで表示
print(f"私の名前は{last_name}{first_name}です。妹の名前は{sister_name}です。")

# 以前の記載
print("私の名前は{}{}です.".format(last_name, first_name))
# Out:
# 私の名前は侍太郎です。妹の名前は花子です。
# 私の名前は侍太郎です.

# %%
# 5.6 変数名のつけ方ルール（命名規則）
# 省略

# %% [markdown]
# ### **実践: 以下の100と30を変数に格納し、以下の結果を出力してください。その際、fを用いてください。**
# 100から30を引くと70になる。

# %% [markdown]
# ### **実践: 以下をスネークケースで変数名定義してください**
# * 家族の人数
# * 算数の点数
# * 子供の名前

# %% [markdown]
# # 課題: 変数を使って四則演算しよう

# %% [markdown]
# # 課題後の実践:
# 1. 以下の処理をgithubにアップロードする
#     1. 3つの変数を用いる
#     2. 文字列と数値２つを変数に代入する
#     3. fを用いてすべてをアンダーバーで結合した結果を出力する
