# %% [markdown]
# # 7章 畳み込みニューラルネットワーク（CNN）とは

# %% [markdown]
# * 畳み込み層
# ![畳み込み1.png](data:image/png;base64,...)

# %% [markdown]
# ![畳み込み2.png](data:image/png;base64,...)

# %% [markdown]
# * プーリング層: 縦・横方向の空間を小さくする演算
# 以下はMaxPoolingの例
# ![プーリング層.png](data:image/png;base64,...)

# %%
# 基本は講義資料の読解

# %% [markdown]
# # 8章 Kerasで画像（CIFAR-10）を判定するCNNを構築しよう #1

# %% [markdown]
# # 9章 Kerasで画像（CIFAR-10）を判定するCNNを構築しよう #2
